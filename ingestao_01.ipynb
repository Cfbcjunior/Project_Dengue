# %%
from pyspark.sql.functions import col

df = spark.read \
    .option("header", True) \
    .option("inferSchema", True) \
    .csv("/Volumes/workspace/default/dengue/*.csv")

df = df.withColumn(
    "arquivo_origem",
    col("_metadata.file_path")
)

display(df)

# %%
print(df.count())

# %%
df.printSchema()
